# %%
def plot_metrics(history,save=False,comment='p'):
    my_fig = plt.figure(figsize=(16, 8),constrained_layout=True)
    gs = my_fig.add_gridspec(2, 3)

    ax1 = my_fig.add_subplot(gs[0, :1])

    ax1.set_title('Обучение: средняя квадратическая ошибка')
    ax1.plot(history.history['out_1_mean_squared_error'],label='CA')
    ax1.plot(history.history['out_2_mean_squared_error'],label='DF')
    ax1.plot(history.history['out_3_mean_squared_error'],label='DJ')
    ax1.legend()

    ax2 = my_fig.add_subplot(gs[0, 1])
    ax2.set_title('Обучение:средняя абсолютная ошибка')
    ax2.plot(history.history['out_1_mean_absolute_error'],label='CA')
    ax2.plot(history.history['out_2_mean_absolute_error'],label='DF')
    ax2.plot(history.history['out_3_mean_absolute_error'],label='DJ')
    ax2.legend()

    ax3 = my_fig.add_subplot(gs[0, 2])
    ax3.set_title('Обучение:средняя абсолютная процентная ошибка')
    ax3.plot(history.history['out_1_mean_absolute_percentage_error'],label='CA')
    ax3.plot(history.history['out_2_mean_absolute_percentage_error'],label='DF')
    ax3.plot(history.history['out_3_mean_absolute_percentage_error'],label='DG')
    ax3.legend()

    ax4 = my_fig.add_subplot(gs[1, :1])
    ax4.set_title('Валидация: средняя квадратическая ошибка')
    ax4.plot(history.history['val_out_1_mean_squared_error'],label='CA')
    ax4.plot(history.history['val_out_2_mean_squared_error'],label='DF')
    ax4.plot(history.history['val_out_3_mean_squared_error'],label='DG')
    ax4.legend()

    ax5 = my_fig.add_subplot(gs[1, 1])
    ax5.set_title('Валидация: средняя абсолютная ошибка')
    ax5.plot(history.history['val_out_1_mean_absolute_error'],label='CA')
    ax5.plot(history.history['val_out_2_mean_absolute_error'],label='DF')
    ax5.plot(history.history['val_out_3_mean_absolute_error'],label='DG')
    ax5.legend()

    ax6 = my_fig.add_subplot(gs[1, 2])
    ax6.set_title('Валидация: средняя абсолютная процентная ошибка')
    ax6.plot(history.history['val_out_1_mean_absolute_percentage_error'],label='CA')
    ax6.plot(history.history['val_out_2_mean_absolute_percentage_error'],label='DF')
    ax6.plot(history.history['val_out_3_mean_absolute_percentage_error'],label='DG')
    ax6.legend()
    if save: my_fig.savefig('plots/'+comment+dateTime(datetime)+'.png') 

def plot_metrics_unique(history,save=False,comment='p',mylable='IPP'):
    my_fig = plt.figure(figsize=(16, 8),constrained_layout=True)
    gs = my_fig.add_gridspec(2, 3)

    ax1 = my_fig.add_subplot(gs[0, :1])

    ax1.set_title('Обучение: средняя квадратическая ошибка')
    ax1.plot(history.history['mean_squared_error'],label=mylable)
    ax1.legend()

    ax2 = my_fig.add_subplot(gs[0, 1])
    ax2.set_title('Обучение:средняя абсолютная ошибка')
    ax2.plot(history.history['mean_absolute_error'],label=mylable)
    ax2.legend()

    ax3 = my_fig.add_subplot(gs[0, 2])
    ax3.set_title('Обучение:средняя абсолютная процентная ошибка')
    ax3.plot(history.history['mean_absolute_percentage_error'],label=mylable)

    ax3.legend()

    ax4 = my_fig.add_subplot(gs[1, :1])
    ax4.set_title('Валидация: средняя квадратическая ошибка')
    ax4.plot(history.history['val_mean_squared_error'],label=mylable)
    ax4.legend()

    ax5 = my_fig.add_subplot(gs[1, 1])
    ax5.set_title('Валидация: средняя абсолютная ошибка')
    ax5.plot(history.history['val_mean_absolute_error'],label=mylable)
    ax5.legend()

    ax6 = my_fig.add_subplot(gs[1, 2])
    ax6.set_title('Валидация: средняя абсолютная процентная ошибка')
    ax6.plot(history.history['val_mean_absolute_percentage_error'],label=mylable)
    ax6.legend()
    if save: my_fig.savefig('plots/'+comment+dateTime(datetime)+'.png')
